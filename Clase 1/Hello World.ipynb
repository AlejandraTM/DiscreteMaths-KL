# %% [markdown]
# <center><h1>🎉Esta es nuestra primera presentación🎉</h1></center><br>
# <center><img src="https://img.europapress.es/fotoweb/fotonoticia_20180108073436_420.jpg"  width="300"
#      height="241"></center>

# %%
print("Hola mundo.")
# Out:
# Hola mundo.

# %% [markdown]
# <h3>🤗 Podemos editar en tiempo real códigos y texto.</h3>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,10,100)
y=np.sin(x)

plt.plot(x,y)
plt.title("Hello Plot")
plt.show()

# %% [markdown]
# <center><h3>🤷‍♀️¿Qué puede ser mejor? 🤷‍♀️</h3></center>
#
# <center><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRyqOQPec2Hk2vvsVbOviiyJMMjzDtjw9JrDg&usqp=CAU"></center>

# %% [markdown]
# <center><p>Con GitHub es posible que tú presentación se abra como una página web desde cualquier parte.</p>
# <img src="https://i.pinimg.com/originals/e4/42/7f/e4427f0dd45c8f0c743eb504be44203b.jpg"></center>
